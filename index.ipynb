# %%
import pandas as pd
# !pip install mapclassify
import mapclassify
from sklearn.preprocessing import RobustScaler
df_educacion = pd.read_csv('C:/Users/USUARIO/Pictures/Saved Pictures/Education.csv')
df_electricidad = pd.read_csv('C:/Users/USUARIO/Pictures/Saved Pictures/Electricity.csv')
df_energia = pd.read_csv('C:/Users/USUARIO/Pictures/Saved Pictures/Energy.csv')
df_reservas = pd.read_csv('C:/Users/USUARIO/Pictures/Saved Pictures/Reserves.csv')
# Out:
# Requirement already satisfied: mapclassify in c:\users\usuario\anaconda3\lib\site-packages (2.8.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\usuario\anaconda3\lib\site-packages (from mapclassify) (3.3)
# Requirement already satisfied: numpy>=1.23 in c:\users\usuario\anaconda3\lib\site-packages (from mapclassify) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in c:\users\usuario\anaconda3\lib\site-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\usuario\anaconda3\lib\site-packages (from mapclassify) (1.5.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\usuario\anaconda3\lib\site-packages (from mapclassify) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %%
# Nombres de columnas para inspeccion
print("Columnas df_educacion:", df_educacion.columns)
print("Columnas df_reservas:", df_reservas.columns)
print("Columnas df_electricidad:", df_electricidad.columns)
print("Columnas df_energia:", df_energia.columns)
# Out:
# Columnas df_educacion: Index(['name', 'slug', '% of GDP', 'date_of_information', 'ranking', 'region'], dtype='object')
# Columnas df_reservas: Index(['name', 'slug', 'value', 'date_of_information', 'ranking', 'region'], dtype='object')
# Columnas df_electricidad: Index(['name', 'slug', ' kW', 'date_of_information', 'ranking', 'region'], dtype='object')
# Columnas df_energia: Index(['name', 'slug', ' Btu/person', 'date_of_information', 'ranking',
#        'region'],
#       dtype='object')

# %%
# Limpieza y formateo de electricidad reservas
df_reservas['value'] = df_reservas['value'].astype(str).str.strip()
df_reservas['value'] = df_reservas['value'].str.replace('$', '',)
df_reservas['value'] = df_reservas['value'].str.replace(',', '')
df_reservas['value'] = df_reservas['value'].str.strip()
df_reservas['reserves'] = pd.to_numeric(df_reservas['value'], errors='coerce')

# %%
df_reservas
# Out:
#                       name                   slug          value  \
# 0                    China                  china  3265000000000
# 1                    Japan                  japan  1160000000000
# 2              Switzerland            switzerland   822130000000
# 3                   Russia                 russia   597217000000
# 4                    India                  india   569544000000
# ..                     ...                    ...            ...
# 190            South Sudan            south-sudan       72881000
# 191           Burkina Faso           burkina-faso       49000000
# 192             Montserrat             montserrat       47580000
# 193  Sao Tome and Principe  sao-tome-and-principe       46247000
# 194                Somalia                somalia       30450000
#
#      date_of_information  ranking                             region  \
# 0                   2024        1            East and Southeast Asia
# 1                   2024        2            East and Southeast Asia
# 2                   2024        3                             Europe
# 3                   2023        4                       Central Asia
# 4                   2024        5                         South Asia
# ..                   ...      ...                                ...
# 190                 2023      191                             Africa
# 191                 2017      192                             Africa
# 192                 2017      193  Central America and the Caribbean
# 193                 2023      194                             Africa
# 194                 2014      195                             Africa
#
#           reserves
# 0    3265000000000
# 1    1160000000000
# 2     822130000000
# 3     597217000000
# 4     569544000000
# ..             ...
# 190       72881000
# 191       49000000
# 192       47580000
# 193       46247000
# 194       30450000
#
# [195 rows x 7 columns]

# %%
df_reservas
# Out:
#                       name                   slug          value  \
# 0                    China                  china  3265000000000
# 1                    Japan                  japan  1160000000000
# 2              Switzerland            switzerland   822130000000
# 3                   Russia                 russia   597217000000
# 4                    India                  india   569544000000
# ..                     ...                    ...            ...
# 190            South Sudan            south-sudan       72881000
# 191           Burkina Faso           burkina-faso       49000000
# 192             Montserrat             montserrat       47580000
# 193  Sao Tome and Principe  sao-tome-and-principe       46247000
# 194                Somalia                somalia       30450000
#
#      date_of_information  ranking                             region  \
# 0                   2024        1            East and Southeast Asia
# 1                   2024        2            East and Southeast Asia
# 2                   2024        3                             Europe
# 3                   2023        4                       Central Asia
# 4                   2024        5                         South Asia
# ..                   ...      ...                                ...
# 190                 2023      191                             Africa
# 191                 2017      192                             Africa
# 192                 2017      193  Central America and the Caribbean
# 193                 2023      194                             Africa
# 194                 2014      195                             Africa
#
#           reserves
# 0    3265000000000
# 1    1160000000000
# 2     822130000000
# 3     597217000000
# 4     569544000000
# ..             ...
# 190       72881000
# 191       49000000
# 192       47580000
# 193       46247000
# 194       30450000
#
# [195 rows x 7 columns]

# %%
# Limpieza y formateo de electricidad
df_electricidad[' kW'] = df_electricidad[' kW'].str.replace(',', '')  # Reemplazar comas por puntos (decimales)
df_electricidad['electricity'] = pd.to_numeric(df_electricidad[' kW'], errors='coerce')
df_electricidad = df_electricidad.drop(columns=[' kW'])

# %%
df_electricidad
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                            Japan
# 4                                           Russia
# ..                                             ...
# 206                                       Kiribati
# 207              Falkland Islands (Islas Malvinas)
# 208                                     Montserrat
# 209  Saint Helena, Ascension, and Tristan da Cunha
# 210                                           Niue
#
#                                             slug  date_of_information  \
# 0                                          china                 2023
# 1                                  united-states                 2023
# 2                                          india                 2023
# 3                                          japan                 2023
# 4                                         russia                 2023
# ..                                           ...                  ...
# 206                                     kiribati                 2023
# 207              falkland-islands-islas-malvinas                 2023
# 208                                   montserrat                 2023
# 209  saint-helena-ascension-and-tristan-da-cunha                 2023
# 210                                         niue                 2023
#
#      ranking                             region  electricity
# 0          1            East and Southeast Asia   2949000000
# 1          2                      North America   1235000000
# 2          3                         South Asia    499136000
# 3          4            East and Southeast Asia    361617000
# 4          5                       Central Asia    301926000
# ..       ...                                ...          ...
# 206      207              Australia and Oceania        12000
# 207      208                      South America        10000
# 208      209  Central America and the Caribbean         6000
# 209      210                             Africa         5000
# 210      211              Australia and Oceania         3000
#
# [211 rows x 6 columns]

# %%
# Limpieza y formateo de electricidad de energía
df_energia[' Btu/person'] = df_energia[' Btu/person'].str.replace(',', '')
df_energia['energy'] = pd.to_numeric(df_energia[' Btu/person'], errors='coerce')
df_energia = df_energia.drop(columns=[' Btu/person'])

# %%
df_energia
# Out:
#                                   name                              slug  \
# 0                                Qatar                             qatar
# 1                            Singapore                         singapore
# 2                              Bahrain                           bahrain
# 3                 United Arab Emirates              united-arab-emirates
# 4                               Brunei                            brunei
# ..                                 ...                               ...
# 190                               Chad                              chad
# 191  Congo, Democratic Republic of the  congo-democratic-republic-of-the
# 192           Central African Republic          central-african-republic
# 193                            Burundi                           burundi
# 194                            Somalia                           somalia
#
#      date_of_information  ranking                   region     energy
# 0                   2023        1              Middle East  814308000
# 1                   2023        2  East and Southeast Asia  643259000
# 2                   2023        3              Middle East  554202000
# 3                   2023        4              Middle East  450432000
# 4                   2023        5  East and Southeast Asia  403365000
# ..                   ...      ...                      ...        ...
# 190                 2023      191                   Africa    1502000
# 191                 2023      192                   Africa    1305000
# 192                 2023      193                   Africa     954000
# 193                 2023      194                   Africa     946000
# 194                 2023      195                   Africa     649000
#
# [195 rows x 6 columns]

# %%
#Renombramos la columna de educacion
df_educacion.rename(columns={'% of GDP': 'education'}, inplace=True)

# %%
df_educacion
# Out:
#                  name              slug  education  date_of_information  \
# 0    Marshall Islands  marshall-islands       13.6                 2020
# 1     Solomon Islands   solomon-islands       12.8                 2020
# 2            Kiribati          kiribati       12.4                 2019
# 3           Greenland         greenland       10.2                 2019
# 4             Bolivia           bolivia        9.8                 2020
# ..                ...               ...        ...                  ...
# 192  Papua New Guinea  papua-new-guinea        1.4                 2020
# 193         Venezuela         venezuela        1.3                 2017
# 194            Monaco            monaco        1.2                 2019
# 195           Nigeria           nigeria        0.5                 2013
# 196           Somalia           somalia        0.3                 2019
#
#      ranking                   region
# 0          1    Australia and Oceania
# 1          2    Australia and Oceania
# 2          3    Australia and Oceania
# 3          4            North America
# 4          5            South America
# ..       ...                      ...
# 192      193  East and Southeast Asia
# 193      194            South America
# 194      195                   Europe
# 195      196                   Africa
# 196      197                   Africa
#
# [197 rows x 6 columns]

# %%
#Seleccion de columnas qwe quiero
df_reservas = df_reservas[['name', 'region', 'reserves']]
df_educacion = df_educacion[['name', 'region', 'education']]
df_energia = df_energia[['name', 'region', 'energy']]
df_electricidad = df_electricidad[['name', 'region', 'electricity']]

# %%
df_educacion
# Out:
#                  name                   region  education
# 0    Marshall Islands    Australia and Oceania       13.6
# 1     Solomon Islands    Australia and Oceania       12.8
# 2            Kiribati    Australia and Oceania       12.4
# 3           Greenland            North America       10.2
# 4             Bolivia            South America        9.8
# ..                ...                      ...        ...
# 192  Papua New Guinea  East and Southeast Asia        1.4
# 193         Venezuela            South America        1.3
# 194            Monaco                   Europe        1.2
# 195           Nigeria                   Africa        0.5
# 196           Somalia                   Africa        0.3
#
# [197 rows x 3 columns]

# %%
#Combinamos los datos
df_combinado = pd.merge(df_reservas, df_energia, on=['name', 'region'], how='inner')
df_combinado = pd.merge(df_combinado, df_electricidad, on=['name', 'region'], how='inner')
df_combinado = pd.merge(df_combinado, df_educacion, on=['name', 'region'], how='inner')

# %%
df_combinado
# Out:
#                       name                   region       reserves     energy  \
# 0                    China  East and Southeast Asia  3265000000000  113805000
# 1                    Japan  East and Southeast Asia  1160000000000  129504000
# 2              Switzerland                   Europe   822130000000   99578000
# 3                   Russia             Central Asia   597217000000  224858000
# 4                    India               South Asia   569544000000   25179000
# ..                     ...                      ...            ...        ...
# 171                   Togo                   Africa       77800000    4538000
# 172            South Sudan                   Africa       72881000    2092000
# 173           Burkina Faso                   Africa       49000000    3481000
# 174  Sao Tome and Principe                   Africa       46247000    8875000
# 175                Somalia                   Africa       30450000     649000
#
#      electricity  education
# 0     2949000000        3.6
# 1      361617000        3.4
# 2       26502000        5.2
# 3      301926000        3.7
# 4      499136000        4.5
# ..           ...        ...
# 171       326000        4.0
# 172       136000        1.5
# 173       749000        5.5
# 174        29000        5.0
# 175       156000        0.3
#
# [176 rows x 6 columns]

# %%
#sacamos la media, min y maximo de datos por region
resumen_region = df_combinado.groupby('region')[['reserves', 'energy', 'electricity', 'education']].agg(['mean', 'min', 'max'])
resumen_region

# %%
# Agrupamos por intervalos
#Rescalado de datos gigantes (energia,electricida) y usamos Quantiles
Vars = ['reserves', 'energy', 'electricity']
scaler = RobustScaler(unit_variance=True, with_centering=False)
robScaled_data = scaler.fit_transform(df_combinado[vars])
vars_rob_names = [v + '_rob' for v in vars]
df_combinado[vars_rob_names] = robScaled_data
for var_rob in vars_rob_names:
    q5 = mapclassify.Quantiles(df_combinado[var_rob], k=5)
    col_name = var_rob.replace('_rob', '') + '_level'
    df_combinado[col_name] = q5.yb + 1

# %%
#educacion clasificacion
K = 5
q5 = mapclassify.Quantiles(df_combinado['education'], k=K)
df_combinado['education_level'] = q5.yb + 1

# %%
#Definimos una varibles con las columnas obtenidas
df_final = df_combinado[[
    'name', 'region',
    'reserves', 'energy', 'electricity', 'education',
    'reserves_level', 'energy_level', 'electricity_level', 'education_level'
]]

# %%
df_final
# Out:
#                       name                   region       reserves     energy  \
# 0                    China  East and Southeast Asia  3265000000000  113805000
# 1                    Japan  East and Southeast Asia  1160000000000  129504000
# 2              Switzerland                   Europe   822130000000   99578000
# 3                   Russia             Central Asia   597217000000  224858000
# 4                    India               South Asia   569544000000   25179000
# ..                     ...                      ...            ...        ...
# 171                   Togo                   Africa       77800000    4538000
# 172            South Sudan                   Africa       72881000    2092000
# 173           Burkina Faso                   Africa       49000000    3481000
# 174  Sao Tome and Principe                   Africa       46247000    8875000
# 175                Somalia                   Africa       30450000     649000
#
#      electricity  education  reserves_level  energy_level  electricity_level  \
# 0     2949000000        3.6               5             5                  5
# 1      361617000        3.4               5             5                  5
# 2       26502000        5.2               5             4                  4
# 3      301926000        3.7               5             5                  5
# 4      499136000        4.5               5             2                  5
# ..           ...        ...             ...           ...                ...
# 171       326000        4.0               1             1                  1
# 172       136000        1.5               1             1                  1
# 173       749000        5.5               1             1                  2
# 174        29000        5.0               1             2                  1
# 175       156000        0.3               1             1                  1
#
#      education_level
# 0                  2
# 1                  2
# 2                  4
# 3                  2
# 4                  3
# ..               ...
# 171                3
# 172                1
# 173                4
# 174                4
# 175                1
#
# [176 rows x 10 columns]
